# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Обработка-признака-balcony" data-toc-modified-id="Обработка-признака-balcony-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Обработка признака balcony</a></span></li><li><span><a href="#Обработка-признака-is_apartment" data-toc-modified-id="Обработка-признака-is_apartment-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Обработка признака is_apartment</a></span></li><li><span><a href="#Работа-с-ceiling_height" data-toc-modified-id="Работа-с-ceiling_height-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Работа с ceiling_height</a></span></li><li><span><a href="#Обработка-значений-в-rooms" data-toc-modified-id="Обработка-значений-в-rooms-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Обработка значений в rooms</a></span></li><li><span><a href="#Работаем-с-locality_name" data-toc-modified-id="Работаем-с-locality_name-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Работаем с locality_name</a></span></li><li><span><a href="#Работаем-с-living_area-и-kitchen_area." data-toc-modified-id="Работаем-с-living_area-и-kitchen_area.-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Работаем с living_area и kitchen_area.</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#цена-квадратного-метра" data-toc-modified-id="цена-квадратного-метра-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>цена квадратного метра</a></span></li><li><span><a href="#день-недели,-месяц-и-год-публикации-объявления" data-toc-modified-id="день-недели,-месяц-и-год-публикации-объявления-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>день недели, месяц и год публикации объявления</a></span></li><li><span><a href="#этаж-квартиры-(варианты-—-первый,-последний,-другой)" data-toc-modified-id="этаж-квартиры-(варианты-—-первый,-последний,-другой)-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>этаж квартиры (варианты — первый, последний, другой)</a></span></li><li><span><a href="#соотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей" data-toc-modified-id="соотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>соотношение жилой и общей площади, а также отношение площади кухни к общей</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Постройте-гистограммы-для-каждого-параметра." data-toc-modified-id="Изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Постройте-гистограммы-для-каждого-параметра.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра.</a></span></li><li><span><a href="#Уберите-редкие-и-выбивающиеся-значения." data-toc-modified-id="Уберите-редкие-и-выбивающиеся-значения.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Уберите редкие и выбивающиеся значения.</a></span></li><li><span><a href="#Изучите-время-продажи-квартиры.-Постройте-гистограмму.-Посчитайте-среднее-и-медиану.-Опишите,-сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго?" data-toc-modified-id="Изучите-время-продажи-квартиры.-Постройте-гистограмму.-Посчитайте-среднее-и-медиану.-Опишите,-сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго?-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?</a></span></li><li><span><a href="#Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?" data-toc-modified-id="Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Какие факторы больше всего влияют на стоимость квартиры?</a></span></li><li><span><a href="#Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитайте-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделите-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья." data-toc-modified-id="Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитайте-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделите-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья.</a></span></li><li><span><a href="#выяснить,-какая-область-входит-в-центр" data-toc-modified-id="выяснить,-какая-область-входит-в-центр-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>выяснить, какая область входит в центр</a></span></li><li><span><a href="#Выделите-сегмент-квартир-в-центре.-Проанализируйте-эту-территорию-и-изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделите-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделайте-выводы.-Отличаются-ли-они-от-общих-выводов-по-всей-базе?" data-toc-modified-id="Выделите-сегмент-квартир-в-центре.-Проанализируйте-эту-территорию-и-изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделите-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделайте-выводы.-Отличаются-ли-они-от-общих-выводов-по-всей-базе?-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.
#
# # Описание данных
#
# * `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м)
# * `balcony` — число балконов
# * `ceiling_height` — высота потолков (м)
# * `cityCenters_nearest` — расстояние до центра города (м)
# * `days_exposition` — сколько дней было размещено объявление (от публикации до снятия)
# * `first_day_exposition` — дата публикации
# * `floor` — этаж
# * `floors_total` — всего этажей в доме
# * `is_apartment` — апартаменты (булев тип)
# * `kitchen_area` — площадь кухни в квадратных метрах (м²)
# * `last_price` — цена на момент снятия с публикации
# * `living_area` — жилая площадь в квадратных метрах (м²)
# * `locality_name` — название населённого пункта
# * `open_plan` — свободная планировка (булев тип)
# * `parks_around3000` — число парков в радиусе 3 км
# * `parks_nearest` — расстояние до ближайшего парка (м)
# * `ponds_around3000` — число водоёмов в радиусе 3 км
# * `ponds_nearest` — расстояние до ближайшего водоёма (м)
# * `rooms` — число комнат
# * `studio` — квартира-студия (булев тип)
# * `total_area` — площадь квартиры в квадратных метрах (м²)
# * `total_images` — число фотографий квартиры в объявлении

# %% [markdown]
# ## Изучение данных из файла

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %%
pd.set_option('chained_assignment', None)

# %%
df = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
df.head()
df1 = df.copy #на случай если надо будет сравнить с оригиналом

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
df.isna().sum().sort_values() # смотрим пропуски в метриках, на основе которых будем строить прогнозы и выводы.
# Out:
# total_images                0
# open_plan                   0
# floor                       0
# rooms                       0
# studio                      0
# total_area                  0
# last_price                  0
# first_day_exposition        0
# locality_name              49
# floors_total               86
# living_area              1903
# kitchen_area             2278
# days_exposition          3181
# ponds_around3000         5518
# parks_around3000         5518
# cityCenters_nearest      5519
# airports_nearest         5542
# ceiling_height           9195
# balcony                 11519
# ponds_nearest           14589
# parks_nearest           15620
# is_apartment            20924
# dtype: int64

# %%
df.describe().T
# Out:
#                        count          mean           std      min         25%  \
# total_images         23699.0  9.858475e+00  5.682529e+00      0.0        6.00
# last_price           23699.0  6.541549e+06  1.088701e+07  12190.0  3400000.00
# total_area           23699.0  6.034865e+01  3.565408e+01     12.0       40.00
# rooms                23699.0  2.070636e+00  1.078405e+00      0.0        1.00
# ceiling_height       14504.0  2.771499e+00  1.261056e+00      1.0        2.52
# floors_total         23613.0  1.067382e+01  6.597173e+00      1.0        5.00
# living_area          21796.0  3.445785e+01  2.203045e+01      2.0       18.60
# floor                23699.0  5.892358e+00  4.885249e+00      1.0        2.00
# kitchen_area         21421.0  1.056981e+01  5.905438e+00      1.3        7.00
# balcony              12180.0  1.150082e+00  1.071300e+00      0.0        0.00
# airports_nearest     18157.0  2.879367e+04  1.263088e+04      0.0    18585.00
# ...

# %% [markdown]
# Посмотрим на распределение целевой переменной

# %%
df.last_price.describe()
# Out:
# count    2.369900e+04
# mean     6.541549e+06
# std      1.088701e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.650000e+06
# 75%      6.800000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %%
ax = df.last_price.plot(kind='box')
ax.set_title('Распределение стоимости')
plt.show()

# %% [markdown]
# Очень большой разброс величины. Посмотрим, что можно исключить.

# %%
df.query("last_price>3e7").shape
# Out:
# (316, 22)

# %% [markdown]
# Чуть более 1% данных, но после удаления сократим разброс переменной более чем в два раза. Удаляем

# %%
df = df.query("last_price<3e7")

# %%
df.last_price.hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Получили положительное унимодальное ассиметричное распределение с хвостом справа.

# %% [markdown]
# ## Предобработка данных
# ---
# Признаки
# ceiling_height, is_apartment
# имеют большое количество пропусков, предположительно, могут значительно влиять на стоимость, кандидаты на заполение.
# Пропуски в balcony заполним по рекомендации.

# %% [markdown]
# ### Обработка признака balcony

# %%
df.balcony.fillna(0, inplace=True)

# %% [markdown]
# ### Обработка признака is_apartment

# %% [markdown]
# Исправим тип признака is_apartment

# %%
df['is_apartment'].astype(bool)
# Out:
# 0        True
# 1        True
# 2        True
# 4        True
# 5        True
#          ...
# 23694    True
# 23695    True
# 23696    True
# 23697    True
# 23698    True
# Name: is_apartment, Length: 23373, dtype: bool

# %%
df['is_apartment'].value_counts()
# Out:
# False    2695
# True       43
# Name: is_apartment, dtype: int64

# %% [markdown]
# Видим, что основная часть существующих значений имеет False.
# Находить корреляцию с булевой признаком мы не учились. Поcмотрим на зависимость с медианной стоимостью.

# %%
ax = df.query("is_apartment==True")['last_price'].plot(kind='box', grid=True)
ax.set_title("распределение цены аппартаментов")
sns.set(rc = {'figure.figsize':(7,7)})
plt.show()

# %%
ax = df.query("is_apartment==False")['last_price'].plot(kind='box')
ax.set_title("распределение цены у НЕ аппартаментов")
plt.show()

# %% [markdown]
# Выяснилось, что признак is_apartment незначительно влияет на медианную стоимость.
# Значение False у этого признака приводит к значительным выбросам цен в сторону больших значений, но это скорее всего обусловлено тем, что таких значений большинство.

# %%
#df.is_apartment.fillna(False, inplace=True) # все таки не будем заполнять пропуски, тем более в исследовании этот признак не участвует.

# %% [markdown]
# ### Работа с ceiling_height

# %%
df.ceiling_height.describe()
# Out:
# count    14285.000000
# mean         2.762879
# std          1.267058
# min          1.000000
# 25%          2.500000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %%
ax = df['ceiling_height'].plot(kind='box', grid=True)
ax.set_title("распределение высоты потолков")
plt.show()

# %% [markdown]
# Видим, что есть выбросы. Глянем на них.

# %%
df.query("1<=ceiling_height>10").head()
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 355             17   3600000.0        55.2  2018-07-12T00:00:00      2
# 3148            14   2900000.0        75.0  2018-11-12T00:00:00      3
# 4643             0   4300000.0        45.0  2018-02-01T00:00:00      2
# 4876             7   3000000.0        25.0  2017-09-27T00:00:00      0
# 5076             0   3850000.0        30.5  2018-10-03T00:00:00      1
#
#       ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 355             25.0           5.0         32.0      2        False   False
# 3148            32.0           3.0         53.0      2          NaN   False
# 4643            25.0           9.0         30.0      2          NaN   False
# 4876            27.0          25.0         17.0     17          NaN   False
# 5076            24.0           5.0         19.5      1         True   False
#
#       open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# Очень похоже, что в части данных имеет ошибка кратности в размерности. Исправим явные выбросы (1 и 100) и подправим ошибку кратности.

# %%
df['ceiling_height'] = df['ceiling_height'].apply(lambda x: np.nan if x==1 or x == 100 else x)

# %%
df['ceiling_height'] = df['ceiling_height'].apply(lambda x: x/10 if  10<x<100 else x)

# %%
df['ceiling_height'].describe()
# Out:
# count    14283.000000
# mean         2.718425
# std          0.278185
# min          1.030000
# 25%          2.500000
# 50%          2.650000
# 75%          2.800000
# max          8.300000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Пропусков достаточно много.

# %%
ax = df['ceiling_height'].plot(kind='box', grid=True)
ax.set_title("распределение высоты потолков")
plt.show()

# %%
df.query("ceiling_height<2 or ceiling_height>4").shape[0]
# Out:
# 39

# %% [markdown]
# Возможно, это продажа нестандартной недвижимости, например какие то склады, подвалы, или наоборот дворцы :) Значений удалим их.
# (Я немного увеличил нижную границу)

# %%
df = df.drop(df.query("ceiling_height<2 or ceiling_height>4").index)

# %%
df.shape
# Out:
# (23334, 22)

# %%
ax = df['ceiling_height'].plot(kind='box') # уже лучше
ax.set_title("распределение высоты потолка после очистки")
plt.show()

# %%
df['ceiling_height'].isna().sum()
# Out:
# 9090

# %% [markdown]
# Вспоминаем, что пропусков очень много.  Как правило, высота потолков зданий зависит от года постройки, а год постройки обычно, влияет на этажность здания. Попробуем заполнить пропуски исходя из этого.

# %%
df_t = df[['total_area', 'rooms', 'cityCenters_nearest','last_price', 'floors_total','ceiling_height']]
sns.pairplot(df_t)
plt.title('Диаграмма зависимости')
plt.show()

# %% [markdown]
# В целом графики мало что дают для понимания.

# %% [markdown]
# Построим боксплоты высоты потолков с группировкой по этажностям.

# %%
df_t = df[['floors_total', 'ceiling_height']]

sns.set(rc = {'figure.figsize':(17,10)})
sns.boxplot(data = df_t, x = 'floors_total', y = 'ceiling_height')
plt.show()

# %% [markdown]
# Видим явные зависимости за исключением некоторых неявных (этажи 1-8), но и там мы видим разные медианы в диапазоне от 2.5 до 3 м. Заполнение на основе этажности зданий внесет меньше искажений в датасет.

# %%
ceiling_height_medians = df.pivot_table(index='floors_total', values='ceiling_height', aggfunc=['median', 'count'])
ceiling_height_medians.columns = ['median', 'count']
ceiling_height_medians.head()
# Out:
#               median  count
# floors_total
# 1.0             2.80     10
# 2.0             2.70    212
# 3.0             2.80    383
# 4.0             3.00    772
# 5.0             2.55   3616

# %% [markdown]
# Заполним пропуски "этажными медианами":

# %%
for floor in ceiling_height_medians.index:
    df.loc[(df['ceiling_height'].isna()) & (df['floors_total'] == floor), 
           'ceiling_height'] = ceiling_height_medians.loc[floor, 'median']

# %%
df['ceiling_height'].isna().sum()
# Out:
# 77

# %%
df[df['ceiling_height'].isna()].head()
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 186             12  11640000.0        65.2  2018-10-02T00:00:00      2
# 237              4   2438033.0        28.1  2016-11-23T00:00:00      1
# 457              4   9788348.0        70.8  2015-08-01T00:00:00      2
# 671              4   6051191.0        93.6  2017-04-06T00:00:00      3
# 1757             5   3600000.0        39.0  2017-04-22T00:00:00      1
#
#       ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 186              NaN           NaN        30.80      4          NaN   False
# 237              NaN           NaN        20.75      1          NaN   False
# 457              NaN           NaN        38.40     12          NaN   False
# 671              NaN           NaN        47.10      8          NaN   False
# 1757             NaN           NaN          NaN      9          NaN   False
#
#       open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# Осталось совсем немного пропусков из за отстуствующих значений floors_total. Заполним их медианным значенем:

# %%
df['ceiling_height'].fillna(df['ceiling_height'].median(), inplace=True)
df['ceiling_height'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Обработка значений в rooms

# %%
df['rooms'].value_counts() # пропусков тут нет. Но есть значение 0.
# Out:
# 1     8031
# 2     7909
# 3     5698
# 4     1106
# 5      265
# 0      195
# 6       75
# 7       36
# 8        7
# 9        6
# 10       2
# 14       2
# 16       1
# 11       1
# Name: rooms, dtype: int64

# %%
df.query("rooms==0")['living_area'].describe()
# Out:
# count    182.000000
# mean      18.595275
# std        5.451767
# min        2.000000
# 25%       16.000000
# 50%       18.000000
# 75%       19.875000
# max       60.500000
# Name: living_area, dtype: float64

# %% [markdown]
# Площадь большей часть выборки соотв-ет площади однокомнатной квартиры. Логично заменить 0 на 1.

# %%
df.query("rooms==0").shape #Студия — это однокомнатная квартира без перегородок.Заполним нули единицами в т.ч. и у студий.
# Out:
# (195, 22)

# %%
df.loc[(df.rooms == 0), 'rooms'] = 1

# %% [markdown]
# ### Работаем с locality_name

# %%
df['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %% [markdown]
# Явно бросается в глаза дублирование из-за "посЁлок" и "посЕлок". Жаль, не пользовались единым реестром КЛАДР.

# %%
df['locality_name'].nunique()
# Out:
# 364

# %%
def replace_pos(name):
    try:
        if name.split()[0] in ['посёлок', 'поселок']:
            name = ' '.join(['посёлок'] + name.split()[1:])
        return name
    except:
        return name

# %%
print(replace_pos('поселок Запорожское')) #проверим
# Out:
# посёлок Запорожское

# %%
df['locality_name'] = df['locality_name'].apply(replace_pos)

# %%
df['locality_name'].nunique()
# Out:
# 331

# %% [markdown]
# Выхлоп небольшой, но уже хорошо :)

# %% [markdown]
# ### Работаем с living_area и kitchen_area.

# %%
df.living_area.isna().sum()
# Out:
# 1862

# %%
df.kitchen_area.isna().sum()
# Out:
# 2237

# %% [markdown]
# У студий S кухни == 0

# %%
df.loc[df.studio==True, 'kitchen_area'] = 0
df.kitchen_area.isna().sum() # и глянем сколько заполнили
# Out:
# 2089

# %%
#sns.scatterplot(x="total_area", y="kitchen_area", alpha=0.4, data=df)
sns.lineplot(x="total_area", y="kitchen_area", alpha=0.6, data=df)
sns.set(rc = {'figure.figsize':(7,7)})
plt.show()

# %%
#sns.scatterplot(x="total_area", y="living_area", alpha=0.4, data=df)
sns.lineplot(x="total_area", y="living_area", alpha=0.6, data=df)
plt.show()

# %% [markdown]
# Будем заполнять пропуски медианой искомой величины у окрестности общей площади (общей площади объекта +- 0.05)
# Как мне показалось, выбрал неплохой способ, не используя сторонние источники :)
# Но перед этим, удалим хвост total_area выше 300 кв.м.

# %%
df = df.query("total_area<300")
df = df.reset_index()

# %%
index_t = df[df['living_area'].isna()].head(10).index
df[df['living_area'].isna()].head()
# Out:
#     index  total_images  last_price  total_area first_day_exposition  rooms  \
# 6       7             5   7915000.0        71.6  2019-04-18T00:00:00      2
# 29     30            12   2200000.0        32.8  2018-02-19T00:00:00      1
# 36     37            10   1990000.0        45.8  2017-10-28T00:00:00      2
# 43     44            13   5350000.0        40.0  2018-11-18T00:00:00      1
# 57     59            15   6300000.0        46.5  2017-03-06T00:00:00      1
#
#     ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 6             2.75          24.0          NaN     22          NaN   False
# 29            2.55           9.0          NaN      2          NaN   False
# 36            2.50           5.0          NaN      1          NaN   False
# 43            2.75          22.0          NaN      3          NaN   False
# 57            2.70          13.0          NaN     13          NaN   False
#
# ...

# %%
for i in df.loc[df['living_area'].isna()].index:
    cur_tot_ar = df.loc[i, 'total_area'] 
    df.loc[i, 'living_area'] =  df.query("@cur_tot_ar*0.95 < total_area < @cur_tot_ar*1.05")\
    ['living_area'].median()

for i in df.loc[df['kitchen_area'].isna()].index:
    cur_kich_ar = df.loc[i, 'kitchen_area'] 
    df.loc[i, 'kitchen_area'] =  df.query("@cur_tot_ar*0.95 < total_area < @cur_tot_ar*1.05")\
    ['kitchen_area'].median()

# %%
df.loc[index_t] # посмотрим, как у нас заполнились пропуски
# Out:
#      index  total_images  last_price  total_area first_day_exposition  rooms  \
# 6        7             5   7915000.0        71.6  2019-04-18T00:00:00      2
# 29      30            12   2200000.0        32.8  2018-02-19T00:00:00      1
# 36      37            10   1990000.0        45.8  2017-10-28T00:00:00      2
# 43      44            13   5350000.0        40.0  2018-11-18T00:00:00      1
# 57      59            15   6300000.0        46.5  2017-03-06T00:00:00      1
# 58      60             3   2740000.0        35.0  2018-01-01T00:00:00      1
# 79      81             9  10949000.0        68.0  2018-12-27T00:00:00      1
# 80      82             3   4500000.0        80.5  2018-01-15T00:00:00      3
# 114    116            18  10999000.0        97.2  2017-11-13T00:00:00      3
# 130    133            12   3150000.0        31.0  2018-03-23T00:00:00      1
#
#      ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %%
print(df.kitchen_area.isna().sum(), df.living_area.isna().sum())
# Out:
# 0 0

# %% [markdown]
# Пропусков нет, данные неплохо соотносятся с реальностью.

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# ### цена квадратного метра

# %%
df['price_per_meter'] = round(df.last_price/df.total_area, 0)

# %% [markdown]
# ### день недели, месяц и год публикации объявления

# %%
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
df['day_exp'] = df['first_day_exposition'].dt.weekday
df['month_exp'] = df['first_day_exposition'].dt.month
df['year_exp'] = df['first_day_exposition'].dt.year

# %% [markdown]
# ### этаж квартиры (варианты — первый, последний, другой)

# %%
def get_floor_type(row):
    floor_type = 'другой'
    if row['floor'] == 1:
        floor_type='первый'
    elif row['floor'] == row['floors_total']:
        floor_type='последний'
    return floor_type

# %%
df['floor_type'] = df.apply(get_floor_type, axis=1)

# %% [markdown]
# ### соотношение жилой и общей площади, а также отношение площади кухни к общей

# %%
df['living_per_total_area'] = round(df.living_area / df.total_area, 3)

# %%
df['kitchen_per_total_area'] = round(df.kitchen_area / df.total_area, 3)

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра.
# ### Уберите редкие и выбивающиеся значения.

# %%
df['rooms'].describe()
# Out:
# count    23323.000000
# mean         2.045063
# std          1.007383
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         16.000000
# Name: rooms, dtype: float64

# %%
ax = df.rooms.plot(kind='box')
ax.set_title('Распределение количества комнат')
plt.show()

# %%
df.query("rooms>=7").shape
# Out:
# (51, 30)

# %%
df = df.query("rooms<7") # минус 51 значение, сокращение разброса почти более чем в 2 раза

# %%
df['ceiling_height'].describe()
# Out:
# count    23272.000000
# mean         2.697433
# std          0.211207
# min          2.000000
# 25%          2.550000
# 50%          2.650000
# 75%          2.750000
# max          4.000000
# Name: ceiling_height, dtype: float64

# %%
ax=df['ceiling_height'].plot(kind='box')
ax.set_title('Распределение высоты потолков, м')
plt.show()

# %% [markdown]
# Есть хвосты, но они значительно меньше. Более того, высота потолков 3-4 метра нередка и непохожа на явные выбросы.

# %% [markdown]
# ### Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?

# %%
df['days_exposition'].describe()
# Out:
# count    20200.000000
# mean       179.181386
# std        217.953708
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        229.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
ax = df['days_exposition'].plot(kind='box', grid=True)
ax.set_title("Распределение сроков продажи, дни")
# Out:
# Text(0.5, 1.0, 'Распределение сроков продажи, дни')

# %% [markdown]
# Медианное значение длительности продаж: 95 дней. Быстрыми продажами можно считать продажи за 45 дней и менее. Есть и значения, который выходят за границы IQR, это продажи более 500 дней, которые можно считать выбросами. Но так как их количество достаточно велико, увеличим границу и исключим такие значения (возьмем границу в 800 дней).

# %%
df.query("days_exposition>800").shape
# Out:
# (567, 30)

# %%
df = df.query("days_exposition<800 or days_exposition.isna()") # очистим данные от нетепично длительных продаж.
df.shape
# Out:
# (22702, 30)

# %% [markdown]
# Потеряли после всех очисток датасета потеряли всего лишь около 5% данных.

# %% [markdown]
# ### Какие факторы больше всего влияют на стоимость квартиры?

# %%
df_t = df[['total_area', 'rooms', 'cityCenters_nearest','last_price']]
df_t.corr()
# Out:
#                      total_area     rooms  cityCenters_nearest  last_price
# total_area             1.000000  0.784619            -0.212915    0.787442
# rooms                  0.784619  1.000000            -0.153747    0.500380
# cityCenters_nearest   -0.212915 -0.153747             1.000000   -0.340880
# last_price             0.787442  0.500380            -0.340880    1.000000

# %% [markdown]
# Построим графики.

# %%
for i in df_t.columns[:-1]:
    sns.jointplot(x=i, y="last_price", alpha=0.4, data=df)
plt.show()

# %% [markdown]
# Вывод: высокая зависимость стоимости от общей площади, видим также зависимость от количества комнат, с ростом количества нижняя граница поднимается. также видно подобие гиперболической зависимости цены от удаленности от центра города, начиная примерно с 10 км ценник начинает падать вниз.

# %%
sns.boxplot(x="floor_type", y="last_price", data=df)
plt.show()

# %% [markdown]
# Вывод: наибольшее значения у категории "другие". Первый этаж традиционно стоит ниже остальных. Промежуточные этажи, что логично, оцениваются выше всех.

# %% [markdown]
# Зависимость от даты размещения: дня недели, месяца и года:

# %%
df_t = df.query('last_price<1.5e7') # уберем хвост, чтобы лучше видеть зависимости.
sns.boxplot(x="day_exp", y="last_price", data=df_t)
plt.show()
sns.boxplot(x="month_exp", y="last_price", data=df_t)
plt.show()
sns.boxplot(x="year_exp", y="last_price", data=df_t)
plt.show()

# %% [markdown]
# Наблюдается небольшой рост стоимости к середине недели, и что странно, к выходным - падает. Но разница мала. Существенного влияния нет.

# %% [markdown]
# Явной зависимости ценника от месяца нет, видим небольшой рост в апреле, и небольшой провал к середине года.

# %% [markdown]
# Зависимость от года: ценник к 2016 году значительно (примерно на треть) упал и мало изменялся до 2018. В 2019 наметился рост стоимости.

# %% [markdown]
# ### Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья.

# %%
df_t = df.groupby('locality_name').agg({'locality_name':'count', 
                                          'price_per_meter': 'mean'})
df_t.rename(columns={'locality_name':'locality_name_count', 
                       'price_per_meter':'price_per_meter_mean'}, 
                        inplace=True)
df_t= df_t.sort_values(by='locality_name_count', ascending=False).reset_index()
df_t.head(10)
# Out:
#        locality_name  locality_name_count  price_per_meter_mean
# 0    Санкт-Петербург                14907         110421.446166
# 1     посёлок Мурино                  543          85822.821363
# 2     посёлок Шушары                  433          78601.224018
# 3         Всеволожск                  388          68644.840206
# 4             Пушкин                  353         102962.141643
# 5            Колпино                  333          75275.828829
# 6  посёлок Парголово                  321          90235.697819
# 7            Гатчина                  297          68892.114478
# 8    деревня Кудрово                  290          92521.279310
# 9             Выборг                  229          58218.938865

# %% [markdown]
# Получили топ 10 городов, кол-во объявлений и ср. цену кв. метра

# %%
df_t[:10].plot(x='locality_name', y = 'locality_name_count', kind='bar')
plt.show()

# %% [markdown]
# Получили наглядное предстваление количества объявлений у топ-10. Большая часть объявлений приходится на Питер, на все остальные - значительно меньше половины

# %%
df_t = df_t.sort_values(by='price_per_meter_mean', ascending=False)
df_t.iloc[[0, -1], :]
# Out:
#           locality_name  locality_name_count  price_per_meter_mean
# 50          Зеленогорск                   24         115122.750000
# 188  деревня Старополье                    3          11206.333333

# %%
df_t.iloc[0:10, :]
# Out:
#          locality_name  locality_name_count  price_per_meter_mean
# 50         Зеленогорск                   24         115122.750000
# 220  посёлок Лисий Нос                    2         113728.500000
# 0      Санкт-Петербург                14907         110421.446166
# 167     посёлок Репино                    4         104238.500000
# 4               Пушкин                  353         102962.141643
# 11          Сестрорецк                  177         102174.118644
# 13             Кудрово                  172         100271.959302
# 81   деревня Мистолово                   11          98550.000000
# 301   посёлок Левашово                    1          96998.000000
# 44              Мурино                   34          92722.705882

# %% [markdown]
# Увидели места с самой недорогим кв. метром и самым дорогим.Разница в ~10 раз впечатляет.
# По стоимости кв. м. С-П находится лишь на третьем месте.

# %% [markdown]
# ### выяснить, какая область входит в центр

# %%
df_t = df.query('locality_name == "Санкт-Петербург"')
df_t.loc[:, 'dist_center_km'] = round(df_t['cityCenters_nearest']/1000) # как избавить от ворнинга?! Так и не смог победить
df_t.head()
# Out:
#    index  total_images  last_price  total_area first_day_exposition  rooms  \
# 0      0            20  13000000.0       108.0           2019-03-07      3
# 2      2            10   5196000.0        56.0           2015-08-20      2
# 3      4             2  10000000.0       100.0           2018-06-19      2
# 6      7             5   7915000.0        71.6           2019-04-18      2
# 8      9            18   5400000.0        61.0           2017-02-26      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 2            2.55           5.0         34.3      4          NaN   False
# 3            3.03          14.0         32.0     13          NaN   False
# 6            2.75          24.0         43.1     22          NaN   False
# 8            2.50           9.0         43.6      7          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
df_t = df_t.pivot_table(
    index='dist_center_km', 
    values='price_per_meter', 
    aggfunc='mean')
df_t = df_t.reset_index()

# %%
sns.lineplot(x='dist_center_km', y='price_per_meter', data=df_t[:15])
plt.show()

# %% [markdown]
# Явное падение стоимости начинается с 7-го км. Имеем также странный провал на 1-3 км.
# Центром будем считать область с радиусом в 7 км.

# %% [markdown]
# ### Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?

# %%
df_t = df.query('locality_name=="Санкт-Петербург" and cityCenters_nearest<=7000')
#df_t = df_t[['last_price', 'price_per_meter',
#         'total_area', 'rooms', 'ceiling_height',
#         'cityCenters_nearest', 'floor', 'first_day_exposition']]
sns.set(rc = {'figure.figsize':(4,4)})

# %%
print(df_t['total_area'].describe())
sns.boxplot(x='total_area', data=df_t)
plt.title('Общая площадь, центр')
plt.show()
sns.boxplot(x='total_area', data=df)
plt.title('Общая площадь, все')
plt.show()
# Out:
# count    2822.000000
# mean       81.601857
# std        37.270563
# min        12.000000
# 25%        55.000000
# 50%        75.000000
# 75%        99.475000
# max       290.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Видим, что медиана общей площади в центре больше общей примерно на половину.

# %%
print(df_t['last_price'].describe())
sns.boxplot(x='last_price', data=df_t)
plt.title('Цена, центр')
plt.show()
sns.boxplot(x='last_price', data=df)
plt.title('Цена, общая')
plt.show()
# Out:
# count    2.822000e+03
# mean     1.023973e+07
# std      5.461477e+06
# min      1.600000e+06
# 25%      6.500000e+06
# 50%      8.600000e+06
# 75%      1.250000e+07
# max      2.999900e+07
# Name: last_price, dtype: float64

# %% [markdown]
# Аналогичная зависимость и для стоимости.

# %%
print(df_t['rooms'].describe())
sns.boxplot(x='rooms', data=df_t)
plt.title('Количество комнат, центр')
plt.show()
sns.boxplot(x='rooms', data=df)
plt.title('Количество комнат, все')
plt.show()
# Out:
# count    2822.000000
# mean        2.654146
# std         1.171027
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max         6.000000
# Name: rooms, dtype: float64

# %% [markdown]
# Медианы 3 против 2 соотв-но, в общем датасете распределение сдвинуто в сторону большего количества однокомнатных и комнат более 4.

# %%
print(df_t['ceiling_height'].describe())
sns.boxplot(x='ceiling_height', data=df_t)
plt.title('Высота потолков, центр')
plt.show()
sns.boxplot(x='ceiling_height', data=df)
plt.title('Высота потолков, все')
plt.show()
# Out:
# count    2822.000000
# mean        2.954695
# std         0.320101
# min         2.400000
# 25%         2.700000
# 50%         3.000000
# 75%         3.100000
# max         4.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# В центре чаще более высокий потолок и равен он 3 м

# %%
df_t.columns
# Out:
# Index(['index', 'total_images', 'last_price', 'total_area',
#        'first_day_exposition', 'rooms', 'ceiling_height', 'floors_total',
#        'living_area', 'floor', 'is_apartment', 'studio', 'open_plan',
#        'kitchen_area', 'balcony', 'locality_name', 'airports_nearest',
#        'cityCenters_nearest', 'parks_around3000', 'parks_nearest',
#        'ponds_around3000', 'ponds_nearest', 'days_exposition',
#        'price_per_meter', 'day_exp', 'month_exp', 'year_exp', 'floor_type',
#        'living_per_total_area', 'kitchen_per_total_area'],
#       dtype='object')

# %%
for column in ['rooms', 'floor', 'day_exp', 'month_exp', 'year_exp']:
    sns.boxplot(x=column, y="last_price", data=df_t)
    plt.title('центр')
    plt.show()
    sns.boxplot(x=column, y="last_price", data=df)
    plt.title('все')
    plt.show()

# %% [markdown]
# В центре  ценник выше по всем параметрам.
# Зависимость от медианного количества комнат лейная положительная.
# От этажа - 1 этаж также самый дешевый. Далее до 10 этажа ценник в целом отличается не сильно, далее встречаются разные цены, в некоторых высотках цены могут быть значительно выше, вероятно это новое элитное жилье.
# Четкой зависимости цены в зависимости от дня нет, есть небольше плавное падение к субботе.
# От месяца - в начале года самая высокая цена, далее падение к маю, плавный рост к ноябрю и странный провал в декабре.
# От года - ситуация та же что и в общем датасете.

# %%
sns.jointplot(x='cityCenters_nearest', y="last_price", data=df_t)
plt.title('центр')
plt.show()
sns.jointplot(x='cityCenters_nearest', y="last_price", data=df)
plt.title('все')
plt.show()

# %%
sns.set(rc = {'figure.figsize':(2,4)})
to_search =['last_price', 'price_per_meter',  'total_area', 'rooms', 'ceiling_height',  
            'cityCenters_nearest', 'floor', 'day_exp', 'month_exp', 'year_exp']
sns.heatmap(df_t[to_search].corr()[['last_price']])
plt.title('Тепловая карта корреляций, центр')
plt.show()
sns.heatmap(df[to_search].corr()[['last_price']])
plt.title('Тепловая карта корреляций, все')
plt.show()

# %% [markdown]
# Степени зависимости в центре и в общем датасете несколько различаются. Но зависимости от признака те же, в порядке убывания: общая площадь, цена за кв.м, количество комнат, этаж, высота потолков.
# При этом последние два признака в центре не сильно влияют на цену.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# <html>
# <head>
# <title>HTML код таблицы, примеры</title>
# </head>
# <body>
# <table border="1">
# <tr>
# <td> &nbsp; </td>
# <td><b>Метраж</b></td>
# <td><b>Цена за квадратный метр</b></td>
# <td><b>Количество комнат</b></td>
# <td><b>Этаж</b></td>
# <td><b>Удаленность от центра</b></td>
# <td><b>Район</b></td>
# <td><b>День размещения объявления</b></td>
# <td><b>Месяц размещения объявления</b></td>
# <td><b>Год размещения объявления</b></td>
# </tr>
# <tr>
# <td style="background-color:#ffffcc"><b>Наблюдения</b> </td>
# <td>Чем больше площадь квартиры, тем выше цена</td>
# <td>Чем больше цена за квадратный метр, тем выше цена</td>
#
# <td>Чем больше комнат, тем выше цена</td>
# <td>На первом этаже квартира дешевле, чем на остальных; на последнем дороже, чем на первом, но дешевле чем на остальных</td>
# <td>Чем ближе к центру, тем дороже квартира. Выявили некоторые отличия зависимости цен в центре</td>
# <td>Есть два района, ценник в которых заметно выше чем в Питере</td>
# <td>Квартиры, размещенные к продаже в будние дни, в среднем дороже, чем размещенные в выходные.</td>
# <td>Квартиры, размещенные к продаже в летние месяцы в среднем дешевле, чем размещенные в любые другие месяца. В начале и в конце года цены поднимаются</td>
# <td>Квартиры, размещенные к продаже в 2014 году, дороже всех. Период 2015-2018 - падение цен, вероятно вызван пониженным спросом из за кризиса. 2019г.- явный рост</td>
# </tr>
# </table>
# </body>
# </html>
